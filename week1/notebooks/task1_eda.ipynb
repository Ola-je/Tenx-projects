# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

from data_loader import load_news_data
from eda import publisher_article_counts, plot_headline_length_dist, plot_articles_over_time, extract_topics, plot_articles_per_day, plot_articles_per_hour, top_publishers, publisher_keywords, extract_email_domains
from task2_analysis import load_stock_data_from_csv, calculate_indicators, plot_stock_with_indicators

df = load_news_data("../data/raw_analyst_ratings.csv")

print(publisher_article_counts(df).head())
plot_headline_length_dist(df)
plot_articles_over_time(df)

# topics = extract_topics(df['headline'], num_topics=5, num_words=6)
# for topic, words in topics:
#     print(topic + ":", ", ".join(words))


plot_articles_per_day(df)
plot_articles_per_hour(df)


print("Top Publishers:")
print(top_publishers(df))

print("\nCommon Keywords by Publisher:")
publisher_keywords(df, top_n=5)

print("\nEmail Domains:")
print(extract_email_domains(df))



# Task 2
df2 = load_stock_data_from_csv('../data/yfinance_data/AAPL_historical_data.csv')
df2 = calculate_indicators(df2)
plot_stock_with_indicators(df2)
# Out:
# C:\Users\kidan.DESKTOP-UUQ68QV\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe
# publisher
# Paul Quintaro        228373
# Lisa Levin           186979
# Benzinga Newsdesk    150484
# Charles Gross         96732
# Monica Gerson         82380
# Name: count, dtype: int64
# Top Publishers:
# publisher
# Paul Quintaro        228373
# Lisa Levin           186979
# Benzinga Newsdesk    150484
# Charles Gross         96732
# Monica Gerson         82380
# Eddie Staley          57254
# Hal Lindon            49047
# ETF Professor         28489
# Juan Lopez            28438
# Benzinga Staff        28114
# Name: count, dtype: int64
#
# Common Keywords by Publisher:
#
# Top words for Paul Quintaro: 00, announces, eps, est, pt, reports, sales, sees, shares, vs
#
# Top words for Lisa Levin: 52, benzinga, biggest, day, market, mid, moving, session, stocks, week
#
# ...
